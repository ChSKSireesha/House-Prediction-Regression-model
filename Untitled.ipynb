# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as plx
import statsmodels.api as sm
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import scipy.stats as stats
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
from sklearn.model_selection import train_test_split,cross_val_score,LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error, mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler,PowerTransformer
from statsmodels.tools.eval_measures import rmse
from statsmodels.stats.outliers_influence import variance_inflation_factor
from mlxtend.feature_selection import SequentialFeatureSelector 
from sklearn.preprocessing import LabelEncoder

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train_df_num = train_df.select_dtypes(include = np.number)

# %%
train_df_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
train_df_num.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
train_df_num["LotFrontage"].fillna(train_df_num["LotFrontage"].median(),inplace = True)

# %%
train_df_num["MasVnrArea"].fillna(train_df_num["MasVnrArea"].median(),inplace = True)

# %%
train_df_num["GarageYrBlt"].fillna(train_df_num["GarageYrBlt"].median(),inplace = True)

# %%
train_df_cat = train_df.select_dtypes(include = "object")

# %%
train_df_cat.isnull().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
train_df_cat.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
train_df_cat["MasVnrType"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["BsmtQual"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["BsmtCond"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["BsmtExposure"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["BsmtFinType1"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["BsmtFinType2"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["FireplaceQu"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["GarageType"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["GarageQual"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["GarageCond"].replace(to_replace = np.nan,value = "None",inplace = True)

# %%
train_df_cat["Alley"].replace(to_replace = np.nan,value = "None",inplace = True)

# %%
train_df_cat["GarageFinish"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["Electrical"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["PoolQC"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["Fence"].replace(to_replace = np.nan,value = "None",inplace = True)
train_df_cat["MiscFeature"].replace(to_replace = np.nan,value = "None",inplace = True)

# %%
train_df_cat["Alley"].unique()
# Out:
# array(['None', 'Grvl', 'Pave'], dtype=object)

# %%
LE = LabelEncoder()
columns_to_encode = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']
for col in columns_to_encode:
    encoded_values = LE.fit_transform(train_df_cat[col])
    train_df_cat[col] = encoded_values

# %%
train_df_cat
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1      1         3            3          0          4
# 1            3       1      1         3            3          0          2
# 2            3       1      1         0            3          0          4
# 3            3       1      1         0            3          0          0
# 4            3       1      1         0            3          0          2
# 5            3       1      1         0            3          0          4
# 6            3       1      1         3            3          0          4
# 7            3       1      1         0            3          0          0
# 8            4       1      1         3            3          0          4
# 9            3       1      1         3            3          0          0
# 10           3       1      1         3            3          0          4
# ...

# %%
final_train_df = pd.concat([train_df_num,train_df_cat],axis = 1)

# %%
final_train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
final_train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
final_train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'MSZoning', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
# ...

# %%
x = final_train_df.drop(columns = ["Id","SalePrice"],axis = 1)
y = final_train_df["SalePrice"]
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.7, test_size = 0.3, random_state = 100)
LR = LinearRegression()
LR.fit(xtrain,ytrain)
train_y_pred = LR.predict(xtrain)
test_y_pred = LR.predict(xtest)
print("RMSE:",np.sqrt(mean_squared_error(ytest,test_y_pred)))
# Out:
# RMSE: 45589.22521501391

# %%
test_df = pd.read_csv("test.csv")
test_df_num = test_df.select_dtypes(exclude = "object")
test_df_num.shape
test_df_num.isnull().sum()
test_df_num["LotFrontage"].fillna(test_df_num["LotFrontage"].median(),inplace = True)
test_df_num["MasVnrArea"].fillna(test_df_num["MasVnrArea"].median(),inplace = True)
test_df_num["BsmtFinSF1"].fillna(test_df_num["BsmtFinSF1"].median(),inplace = True)
test_df_num["BsmtFinSF2"].fillna(test_df_num["BsmtFinSF2"].median(),inplace = True)
test_df_num["BsmtUnfSF"].fillna(test_df_num["BsmtUnfSF"].median(),inplace = True)
test_df_num["TotalBsmtSF"].fillna(test_df_num["TotalBsmtSF"].median(),inplace = True)
test_df_num["BsmtFullBath"].fillna(test_df_num["BsmtFullBath"].median(),inplace = True)
test_df_num["BsmtHalfBath"].fillna(test_df_num["BsmtHalfBath"].median(),inplace = True)
test_df_num["GarageYrBlt"].fillna(test_df_num["GarageYrBlt"].median(),inplace = True)
test_df_num["GarageCars"].fillna(test_df_num["GarageCars"].median(),inplace = True)
test_df_num["GarageArea"].fillna(test_df_num["GarageArea"].median(),inplace = True)

# %%
test_df_num.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %%
test_df_cat = test_df.select_dtypes(include = "object")
test_df_cat.isnull().sum()
# Out:
# MSZoning            4
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType        894
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinType2       42
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# KitchenQual         1
# Functional          2
# FireplaceQu       730
# GarageType         76
# GarageFinish       78
# GarageQual         78
# GarageCond         78
# PavedDrive          0
# PoolQC           1456
# Fence            1169
# MiscFeature      1408
# ...

# %%
test_df_cat["Alley"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["MasVnrType"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["BsmtQual"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["BsmtCond"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["BsmtExposure"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["BsmtFinType1"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["BsmtFinType2"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["FireplaceQu"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["GarageType"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["GarageQual"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["GarageCond"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["GarageFinish"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["Electrical"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["PoolQC"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["Fence"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["MiscFeature"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["MSZoning"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["Exterior1st"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["Exterior2nd"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["KitchenQual"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["Functional"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["SaleType"].replace(to_replace = np.nan,value = "None",inplace = True)
test_df_cat["Utilities"].replace(to_replace = np.nan,value = "None",inplace = True)

# %%
test_df_cat.isnull().sum()
# Out:
# MSZoning         0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# KitchenQual      0
# Functional       0
# FireplaceQu      0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
test_df_cat.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
LE = LabelEncoder()
columns_to_encode = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']
for col in columns_to_encode:
    encoded_values = LE.fit_transform(test_df_cat[col])
    test_df_cat[col] = encoded_values

# %%
final_test_df = pd.concat([test_df_num,test_df_cat],axis = 1)
final_test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0       1961          1961         0.0       468.0       144.0      270.0
# 1       1958          1958       108.0       923.0         0.0      406.0
# 2       1997          1998         0.0       791.0         0.0      137.0
# 3       1998          1998        20.0       602.0         0.0      324.0
# 4       1992          1992         0.0       263.0         0.0     1017.0
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# ...

# %%
test = final_test_df.drop("Id",axis = 1)
actual_pred = LR.predict(test)
test_pred = pd.DataFrame(actual_pred,index = final_test_df["Id"])
final_test  = test_pred.reset_index()
final_test_df.rename(columns={0:"SalePrice"},inplace = True)
final_test_df.to_csv("sub_test_base.csv")

# %%
# Identify significant variables to build a model

# %%
LR = LinearRegression()
LR_forward = SequentialFeatureSelector(estimator = LR,k_features = "best", forward = True,scoring = "r2")
#k-features helps to know the no .of significant variables

LR_forward.fit(xtrain,ytrain)
print("top 5 ind var:",LR_forward.k_feature_names_)
print("score :", LR_forward.k_score_)
# Out:
# top 5 ind var: ('MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'MasVnrArea', 'BsmtUnfSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'YrSold', 'LandContour', 'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 'Fence', 'SaleType')
# score : 0.8217126364139358

# %%
x = final_train_df[['MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'MasVnrArea', 'BsmtUnfSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'YrSold', 'LandContour', 'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 'Fence', 'SaleType']]
y = final_train_df[["SalePrice"]]
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.7, test_size = 0.3, random_state = 100)
LR = LinearRegression()
LR.fit(xtrain,ytrain)
train_y_pred = LR.predict(xtrain)
test_y_pred = LR.predict(xtest)
print("RMSE:",np.sqrt(mean_squared_error(ytest,test_y_pred)))
# Out:
# RMSE: 33575.92944918645

# %%
test = final_test_df[['MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'MasVnrArea', 'BsmtUnfSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'WoodDeckSF', 'YrSold', 'LandContour', 'LandSlope', 'Neighborhood', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', 'Foundation', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 'Fence', 'SaleType']]
actual_pred = LR.predict(test)
test_pred = pd.DataFrame(actual_pred,index = final_test_df["Id"])
final_test  = test_pred.reset_index()
final_test.rename(columns={0:"SalePrice"},inplace = True)
final_test.to_csv("sub_test_sig.csv")

# %%
actual_pred
# Out:
# array([[ 82669.16063029],
#        [160800.21776011],
#        [152727.60537405],
#        ...,
#        [146098.27350868],
#        [100715.91446886],
#        [254671.45110427]])

# %%
train_df_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
# Treat Outliers
boxprops = dict(linewidth=2, facecolor='lightblue')
plt.figure(figsize=(30, 15))
sns.boxplot(data=train_df_num)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
columns_to_check = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal']

for column in columns_to_check:
    Q1 = train_df_num[column].quantile(0.25)
    Q3 = train_df_num[column].quantile(0.75)
    IQR = Q3 - Q1
    UL = Q3 + (1.5 * IQR)
    LL = Q1 - (1.5 * IQR)
    
    row_index = train_df_num[column].index
    for i in row_index:
        if train_df_num.loc[i, column] > UL:
            train_df_num.loc[i, column] = UL
        elif train_df_num.loc[i, column] < LL:
            train_df_num.loc[i, column] = LL

# %%
boxprops = dict(linewidth=2, facecolor='lightblue')
plt.figure(figsize=(30, 15))
sns.boxplot(data=train_df_num)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
final_train_df = pd.concat([train_df_num,train_df_cat],axis = 1)

# %%
x = final_train_df.drop(columns = ["Id","SalePrice"],axis = 1)
y = final_train_df["SalePrice"]
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.7, test_size = 0.3, random_state = 100)
LR = LinearRegression()
LR.fit(xtrain,ytrain)
train_y_pred = LR.predict(xtrain)
test_y_pred = LR.predict(xtest)
print("RMSE:",np.sqrt(mean_squared_error(ytest,test_y_pred)))
# Out:
# RMSE: 30544.967324740224

# %%
test = final_test_df.drop("Id",axis = 1)
actual_pred = LR.predict(test)
test_pred = pd.DataFrame(actual_pred,index = final_test_df["Id"])
final_test  = test_pred.reset_index()
final_test.rename(columns={0:"SalePrice"},inplace = True)
final_test.to_csv("sub_test_win.csv")

# %%
#VIF

# %%
# display the first five observations
train_df_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
train_df_num1 = train_df_num.drop("SalePrice",axis=1)

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

# create an empty dataframe to store the VIF for each variable
vif = pd.DataFrame()

# calculate VIF using list comprehension 
# use for loop to access each variable 
# calculate VIF for each variable and create a column 'VIF_Factor' to store the values 
vif["VIF_Factor"] = [variance_inflation_factor(train_df_num1.values, i) for i in range(train_df_num1.shape[1])]

# create a column of variable names
vif["Features"] = train_df_num1.columns

# sort the dataframe based on the values of VIF_Factor in descending order
# 'ascending = False' sorts the data in descending order
# 'reset_index' resets the index of the dataframe
# 'drop = True' drops the previous index
vif = vif.sort_values('VIF_Factor', ascending = False).reset_index(drop = True)

print(vif)
# Out:
#       VIF_Factor       Features
# 0            inf      BsmtUnfSF
# 1            inf     BsmtFinSF1
# 2            inf      GrLivArea
# 3            inf   LowQualFinSF
# 4            inf       2ndFlrSF
# 5            inf       1stFlrSF
# 6            inf    TotalBsmtSF
# 7            inf     BsmtFinSF2
# 8   2.406168e+04         YrSold
# 9   2.253639e+04    GarageYrBlt
# 10  2.244003e+04   YearRemodAdd
# 11  2.128559e+04      YearBuilt
# 12  8.352543e+01   TotRmsAbvGrd
# 13  6.670052e+01    OverallQual
# 14  4.170905e+01    OverallCond
# 15  3.760617e+01   KitchenAbvGr
# 16  3.681423e+01     GarageCars
# 17  3.218892e+01     GarageArea
# 18  3.109414e+01   BedroomAbvGr
# 19  2.668171e+01       FullBath
# 20  1.734088e+01    LotFrontage
# 21  6.649587e+00         MoSold
# 22  4.652262e+00     MSSubClass
# 23  4.111627e+00             Id
# 24  3.695225e+00   BsmtFullBath
# 25  3.420804e+00       HalfBath
# 26  3.020286e+00     Fireplaces
# 27  2.649185e+00        LotArea
# ...

# %%
# Set the threshold for high VIF
threshold = 10

# Get the features with high VIF
high_vif_features = vif[vif['VIF_Factor'] > threshold]['Features'].tolist()

# Drop the features with high VIF from your dataset
train_df_num_filtered = train_df_num1.drop(high_vif_features, axis=1)

# Display the remaining features after filtering
print("Remaining features after removing high VIF features:")
print(train_df_num_filtered)
# Out:
# Remaining features after removing high VIF features:
#         Id  MSSubClass  LotArea  MasVnrArea  BsmtFullBath  BsmtHalfBath  \
# 0        1          60     8450       196.0             1             0
# 1        2          20     9600         0.0             0             1
# 2        3          60    11250       162.0             1             0
# 3        4          70     9550         0.0             1             0
# 4        5          60    14260       350.0             1             0
# 5        6          50    14115         0.0             1             0
# 6        7          20    10084       186.0             1             0
# 7        8          60    10382       240.0             1             0
# 8        9          50     6120         0.0             0             0
# 9       10         190     7420         0.0             1             0
# 10      11          20    11200         0.0             1             0
# ...

# %%
train_df_num_filtered.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'MasVnrArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'HalfBath', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold'],
#       dtype='object')

# %%
final_train_df = pd.concat([train_df_num_filtered,train_df_cat,train_df_num['SalePrice'],train_df_num['Id']],axis = 1)

# %%
final_train_df.head()
# Out:
#    Id  MSSubClass  LotArea  MasVnrArea  BsmtFullBath  BsmtHalfBath  HalfBath  \
# 0   1          60     8450       196.0             1             0         1
# 1   2          20     9600         0.0             0             1         0
# 2   3          60    11250       162.0             1             0         1
# 3   4          70     9550         0.0             1             0         0
# 4   5          60    14260       350.0             1             0         1
#
#    Fireplaces  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0           0           0           61              0          0            0
# 1           1         298            0              0          0            0
# 2           1           0           42              0          0            0
# 3           1           0           35            272          0            0
# 4           1         192           84              0          0            0
#
# ...

# %%
x = final_train_df.drop(columns = ["Id","SalePrice"],axis = 1)
y = final_train_df["SalePrice"]
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.7, test_size = 0.3, random_state = 100)
LR = LinearRegression()
LR.fit(xtrain,ytrain)
train_y_pred = LR.predict(xtrain)
test_y_pred = LR.predict(xtest)
print("RMSE:",np.sqrt(mean_squared_error(ytest,test_y_pred)))
# Out:
# RMSE: 50074.20996613498

# %%
## Scaling

# %%
b = final_train_df[['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'MSZoning', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
       'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
       'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType',
       'SaleCondition']]
a = ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'MSZoning', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
       'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
       'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType',
       'SaleCondition']

# %%
SS = StandardScaler()
SS.fit_transform(b)
c =pd.DataFrame(SS.fit_transform(b),columns = a)

# %%
x = final_train_df.drop(columns= ["SalePrice","Id"],axis =1)
y = final_train_df["SalePrice"]

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.7, test_size = 0.3, random_state = 100)
LR = LinearRegression()
LR.fit(xtrain,ytrain)
train_y_pred = LR.predict(xtrain)
test_y_pred = LR.predict(xtest)
print("RMSE:",np.sqrt(mean_squared_error(ytest,test_y_pred)))
# Out:
# RMSE: 45589.22521501391
